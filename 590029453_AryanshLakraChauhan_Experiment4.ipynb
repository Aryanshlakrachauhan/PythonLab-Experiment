# %% [markdown]
# Python Programming : Experiment 4 ( Strings and Sets )
#
# Name: Aryansh Lakra Chauhan
#
# Sap_ID: 590029453

# %%
# Q1: Write a program to count and display the number of capital letters in a given string.

s = input("Enter a string: ")
count = 0

for ch in s:
    if ch.isupper():   # check uppercase
        count += 1

print("Number of capital letters:", count)
# Out:
# Enter a string: I am Aryansh
# Number of capital letters: 2

# %%
# Q2: Count total number of vowels in a given string.

s = input("Enter a string: ")
vowels = "aeiouAEIOU"
count = 0

for ch in s:
    if ch in vowels:   # check vowel
        count += 1

print("Total vowels:", count)
# Out:
# Enter a string: hello user
# Total vowels: 4

# %%
# Q3: Input a sentence and print words in separate lines.

sentence = input("Enter a sentence: ")
words = sentence.split()   # split sentence into words

for w in words:
    print(w)
# Out:
# Enter a sentence: hello my name is aryansh
# hello
# my
# name
# is
# aryansh

# %%
# Q4: WAP to enter a string and a substring. You have to print the number of times that the substring occurs in the given string. String traversal will take place from left to right, not from right to left.
string = input("Enter main string: ")
sub = input("Enter substring: ")

count = 0
i = 0

while i <= len(string) - len(sub):
    if string[i:i+len(sub)] == sub:
        count += 1
        i += 1   # move forward
    else:
        i += 1

print(count)
# Out:
# Enter main string: i play cricket and watch cricket matches
# Enter substring: cricket
# 2

# %%
# Q5: Given a string containing both upper and lower case alphabets. Write a Python program to count the number of occurrences of each alphabet (case insensitive) and display the same.

s = input("Enter string: ")
s = s.upper()   # convert to uppercase

freq = {}

for ch in s:
    if ch.isalpha():   # check alphabet
        freq[ch] = freq.get(ch, 0) + 1

for k in sorted(freq):
    print(freq[k], k)
# Out:
# Enter string: Hello user
# 2 E
# 1 H
# 2 L
# 1 O
# 1 R
# 1 S
# 1 U

# %%
# Q6: Program to count number of unique words in a given sentence using sets.

sentence = input("Enter a sentence: ")
words = sentence.split()

unique_words = set(words)   # remove duplicates

print("Number of unique words:", len(unique_words))
# Out:
# Enter a sentence: nice to meet you and see you
# Number of unique words: 6

# %%
# Q7: Create 2 sets s1 and s2 of n fruits each by taking input from user and find:
# a) Fruits which are in both sets s1 and s2
# b) Fruits only in s1 but not in s2
# c) Count of all fruits from s1 and s2

n = int(input("Enter number of fruits: "))

s1 = set()
s2 = set()

print("Enter fruits for set s1:")
for i in range(n):
    s1.add(input())

print("Enter fruits for set s2:")
for i in range(n):
    s2.add(input())

# a) Common fruits
print("Common fruits:", s1 & s2)

# b) Fruits only in s1
print("Only in s1:", s1 - s2)

# c) Count of all fruits
print("Total fruits count:", len(s1 | s2))
# Out:
# Enter number of fruits: 2
# Enter fruits for set s1:
# Mango
# Apple
# Enter fruits for set s2:
# Orange
# Grape
# Common fruits: set()
# Only in s1: {'Mango', 'Apple'}
# Total fruits count: 4

# %%
# Q8: Take two sets and apply various set operations on them :
# S1 = {Red ,yellow, orange , blue }
# S2 = {violet, blue , purple}

S1 = {"Red", "yellow", "orange", "blue"}
S2 = {"violet", "blue", "purple"}

print("Union:", S1 | S2)
print("Intersection:", S1 & S2)
print("Difference S1 - S2:", S1 - S2)
print("Difference S2 - S1:", S2 - S1)
# Out:
# Union: {'purple', 'Red', 'orange', 'violet', 'blue', 'yellow'}
# Intersection: {'blue'}
# Difference S1 - S2: {'Red', 'orange', 'yellow'}
# Difference S2 - S1: {'purple', 'violet'}
