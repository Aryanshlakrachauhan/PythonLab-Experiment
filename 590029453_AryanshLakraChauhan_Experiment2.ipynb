# %% [markdown]
# Python Programming : Experiment 2 ( Conditional Statement )
#
# Name: Aryansh Lakra Chauhan
#
# Sap_ID: 590029453

# %%
# Q1: Check whether the given number is divisible by 3 and 5 both

num = int(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:
    print("Divisible by both 3 and 5")
else:
    print("Not divisible by both")
# Out:
# Enter a number: 15
# Divisible by both 3 and 5

# %%
# Q2: Check whether a given number is multiple of five or not

num = int(input("Enter a number: "))

if num % 5 == 0:
    print("Multiple of 5")
else:
    print("Not a multiple of 5")
# Out:
# Enter a number: 35
# Multiple of 5

# %%
# Q3: Find the greatest among the two numbers. If numbers are equal than print “numbers are equal”.

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Greatest number is:", a)
elif b > a:
    print("Greatest number is:", b)
else:
    print("Numbers are equal")
# Out:
# Enter first number: 34
# Enter second number: 45
# Greatest number is: 45

# %%
# Q4: Find the greatest among three numbers assuming no two values are same

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("Greatest number is:", a)
elif b > a and b > c:
    print("Greatest number is:", b)
else:
    print("Greatest number is:", c)
# Out:
# Enter first number: 67
# Enter second number: 78
# Enter third number: 90
# Greatest number is: 90

# %%
# Q5: Check whether the quadratic equation has real roots or imaginary roots. Display the roots

import math

a = int(input("Enter a: "))
b = int(input("Enter b: "))
c = int(input("Enter c: "))

d = b*b - 4*a*c  # discriminant

if d > 0:
    r1 = (-b + math.sqrt(d)) / (2*a)
    r2 = (-b - math.sqrt(d)) / (2*a)
    print("Real and different roots:", r1, r2)
elif d == 0:
    r = -b / (2*a)
    print("Real and same roots:", r)
else:
    print("Imaginary roots")
# Out:
# Enter a: 3
# Enter b: 4
# Enter c: 5
# Imaginary roots

# %%
# Q6: Find whether a given year is a leap year or not.

year = int(input("Enter year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2000
# Leap Year

# %%
# Q7: Write a program which takes any date as input and display next date of the calendar
day = int(input("Enter day: "))
month = int(input("Enter month: "))
year = int(input("Enter year: "))

# days in each month
days_in_month = [31,28,31,30,31,30,31,31,30,31,30,31]

# leap year check for February
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    days_in_month[1] = 29

day += 1

if day > days_in_month[month-1]:
    day = 1
    month += 1

    if month > 12:
        month = 1
        year += 1

print("Next Date:", day, month, year)
# Out:
# Enter day: 08
# Enter month: 09
# Enter year: 2007
# Next Date: 9 9 2007

# %%
# Q8: Print the grade sheet of a student for the given range of cgpa. Scan marks of five subjects and calculate the percentage

name = input("Enter name: ")
roll = input("Enter roll number: ")

# input marks
m1 = int(input("PDS marks: "))
m2 = int(input("Python marks: "))
m3 = int(input("Chemistry marks: "))
m4 = int(input("English marks: "))
m5 = int(input("Physics marks: "))

total = m1 + m2 + m3 + m4 + m5
percentage = total / 5
cgpa = percentage / 10

# grade decision
if cgpa <= 3.4:
    grade = "F"
elif cgpa <= 5.0:
    grade = "C+"
elif cgpa <= 6.0:
    grade = "B"
elif cgpa <= 7.0:
    grade = "B+"
elif cgpa <= 8.0:
    grade = "A"
elif cgpa <= 9.0:
    grade = "A+"
else:
    grade = "O (Outstanding)"

print("\n--- Grade Sheet ---")
print("Name:", name)
print("Roll No:", roll)
print("Percentage:", percentage)
print("CGPA:", cgpa)
print("Grade:", grade)
# Out:
# Enter name: Aryansh
# Enter roll number: 4
# PDS marks: 98
# Python marks: 98
# Chemistry marks: 96
# English marks: 90
# Physics marks: 89
#
# --- Grade Sheet ---
# Name: Aryansh
# Roll No: 4
# Percentage: 94.2
# CGPA: 9.42
# Grade: O (Outstanding)
