# %% [markdown]
# Python Programming : Experiment 6 ( Function )
#
# Name: Aryansh Lakra Chauhan
#
# Sap_ID: 590029453

# %%
# Q1. Write a Python function to find the maximum and minimum numbers from a sequence of numbers. (Note: Do not use built-in functions.)

def find_max_min(arr):
    max_val = arr[0]
    min_val = arr[0]

    for i in arr:
        if i > max_val:
            max_val = i
        if i < min_val:
            min_val = i

    return max_val, min_val

nums = [10, 6, 8, 90, 12, 56]
print("Max and Min:", find_max_min(nums))
# Out:
# Max and Min: (90, 6)

# %%
# Q2. Write a Python function that takes a positive integer and returns the sum of the cube of all the positive integers smaller than the specified number.

def sum_of_cubes(n):
    total = 0
    for i in range(1, n):
        total += i ** 3
    return total

n = int(input("Enter number: "))
print("Sum of cubes:", sum_of_cubes(n))
# Out:
# Enter number: 4
# Sum of cubes: 36

# %%
# Q3. 6Write a Python function to print 1 to n using recursion. (Note: Do not use loop)

def print_numbers(n):
    if n == 0:
        return
    print_numbers(n - 1)
    print(n)

n = int(input("Enter n: "))
print_numbers(n)
# Out:
# Enter n: 6
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# Q4. Write a recursive function to print Fibonacci series upto n terms.

def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n - 1) + fibonacci(n - 2)

n = int(input("Enter number of terms: "))
for i in range(n):
    print(fibonacci(i), end=" ")
# Out:
# Enter number of terms: 4
# 0 1 1 2

# %%
# Q5. Write a lambda function to find volume of cone.

import math

volume_cone = lambda r, h: (1/3) * math.pi * r * r * h

print("Volume:", volume_cone(3, 5))
# Out:
# Volume: 47.12388980384689

# %%
# Q6. Write a lambda function which gives tuple of max and min from a list.

nums = [10, 6, 8, 90, 12, 56]

result = lambda x: (max(x), min(x))

print("Max and Min:", result(nums))
# Out:
# Max and Min: (90, 6)

# %%
# Q7. Write functions to explain the mentioned concepts:
# a) Keyword Argument
# b) Default Argument
# c) Variable-length Argument

# a) Keyword argument
def student(name, age):
    print(name, age)

student(age=20, name="Rahul")

# b) Default argument
def greet(name="Student"):
    print("Hello", name)

greet()
greet("Amit")

# c) Variable-length argument
def total(*nums):
    s = 0
    for i in nums:
        s += i
    print("Sum:", s)

total(10, 20, 30)
# Out:
# Rahul 20
# Hello Student
# Hello Amit
# Sum: 60

# %%
# Q8. Write a program to check whether all the values in a dictionary are the same or not using a lambda function.

data = {'a': 10, 'b': 10, 'c': 10}

check = lambda d: len(set(d.values())) == 1

print("All values same:", check(data))
# Out:
# All values same: True

# %%
# Q9. Write a program to create two lists and generate a dictionary with keys from list1 and values from list2.

list1 = ['a', 'b', 'c']
list2 = [10, 20, 30]

result = dict(zip(list1, list2))

print("Dictionary:", result)
# Out:
# Dictionary: {'a': 10, 'b': 20, 'c': 30}
